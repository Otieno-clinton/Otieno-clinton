# %% [markdown]
# <a href="https://colab.research.google.com/github/Otieno-clinton/Otieno-clinton/blob/main/simple_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
data = pd.read_excel("/content/child_data.xlsx")

# %%
data.head()
# Out:
#    Age (months)  Sex  Child's weight (kilograms)
# 0            45    0                        16.2
# 1            45    1                        13.5
# 2            36    1                        13.4
# 3            51    0                        15.0
# 4            56    0                        15.2

# %%
data.tail()
# Out:
#      Age (months)  Sex  Child's weight (kilograms)
# 763             7    0                         8.3
# 764             0    1                         3.5
# 765            56    0                        15.1
# 766            18    0                        10.7
# 767             7    0                        10.3

# %%
data.isnull().sum()
# Out:
# Age (months)                  0
# Sex                           0
# Child's weight (kilograms)    0
# dtype: int64

# %%
data.shape
# Out:
# (768, 3)

# %%
data.describe()
# Out:
#        Age (months)         Sex  Child's weight (kilograms)
# count    768.000000  768.000000                  768.000000
# mean      29.151042    0.494792                   11.593490
# std       16.861367    0.500299                    3.408997
# min        0.000000    0.000000                    3.200000
# 25%       14.000000    0.000000                    9.200000
# 50%       30.000000    0.000000                   11.700000
# 75%       43.000000    1.000000                   14.125000
# max       59.000000    1.000000                   25.000000

# %%
data.corr()
# Out:
#                             Age (months)       Sex  Child's weight (kilograms)
# Age (months)                    1.000000 -0.037463                    0.831436
# Sex                            -0.037463  1.000000                    0.036444
# Child's weight (kilograms)      0.831436  0.036444                    1.000000

# %%
data.plot(kind='scatter',x="Age (months)",y="Child's weight (kilograms)", s=32, alpha=.8)
plt.gca().spines[['top','right',]].set_visible(False)

# %% [markdown]
# creating x and y values: x beingthe independent variable and y being the dpendent variable

# %%
x= data[["Age (months)"]]
y= data[["Child's weight (kilograms)"]]

# %% [markdown]
# creating the model

# %%
model=linear_model.LinearRegression()

# %% [markdown]
# splitting the data into 70% training and 30% testing

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (537, 1)
# (231, 1)
# (537, 1)
# (231, 1)

# %% [markdown]
# Training the model

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
print("MSE: ",mean_squared_error(y_test,y_pred))
print("R2 Score: ",r2_score(y_test,y_pred))
print("MAE: ",mean_absolute_error(y_test,y_pred))
print("Accuracy: ",model.score(x_test,y_test))
# Out:
# MSE:  3.76699923173311
# R2 Score:  0.6901916485037674
# MAE:  1.459365198453278
# Accuracy:  0.6901916485037674
