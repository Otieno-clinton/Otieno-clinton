# %% [markdown]
# <a href="https://colab.research.google.com/github/Otieno-clinton/Otieno-clinton/blob/main/Astronomical_data_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
stars_df = pd.read_csv('/content/cleaned_star_data.csv') # reading or loading data from the file

# %%
stars_df.head() # showsh the fisrt five rows of the dataframe
# Out:
#    Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0             3068          0.002400        0.1700                   16.12
# 1             3042          0.000500        0.1542                   16.60
# 2             2600          0.000300        0.1020                   18.70
# 3             2800          0.000200        0.1600                   16.65
# 4             1939          0.000138        0.1030                   20.06
#
#    Star type Star color Spectral Class
# 0          0        Red              M
# 1          0        Red              M
# 2          0        Red              M
# 3          0        Red              M
# 4          0        Red              M

# %%
stars_df.sample(10)
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 60              3341          0.005600        0.0570                  16.230
# 183             3218          0.000452        0.0987                  17.340
# 16              2799          0.001800        0.1600                  14.790
# 125             3225          0.000760        0.1210                  19.630
# 61              3432          0.000670        0.1900                  16.940
# 178            12100     120000.000000      708.9000                  -7.840
# 204            18340          0.001340        0.0124                  11.220
# 194             3523          0.005400        0.3190                  12.430
# 193             3212          0.001600        0.3780                  12.854
# 218            17140        883.000000        5.6530                  -2.640
#
#      Star type  Star color Spectral Class
# 60           0         Red              M
# ...

# %%
stars_df.info() # provide the general information about data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Temperature (K)         240 non-null    int64
#  1   Luminosity(L/Lo)        240 non-null    float64
#  2   Radius(R/Ro)            240 non-null    float64
#  3   Absolute magnitude(Mv)  240 non-null    float64
#  4   Star type               240 non-null    int64
#  5   Star color              240 non-null    object
#  6   Spectral Class          240 non-null    object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 13.2+ KB

# %% [markdown]
# 1) Dataset consist of 240 rows, 6 feature and 1 target columns.
#
# 2) Two categorical features (object type) which will need some kind od encoding
#
# 3) It consist of some different features of stars. Information on the star type is given below,
#
#
# * 0 --- Brown  Dwarf
# * 1 ---Red Dwarf
# * 2--- White Dwarf
# * 3 --- Main sequece
# * 4 --- Supergiants
# * 5 --- Hypergiants

# %%
# creat a directory to save the visualization
folder_name = 'star_plots'
os.makedirs(folder_name, exist_ok= True)
base_dir = f'/content/{folder_name}/'

# %% [markdown]
# We are now visulizing the count of stars for each type of star

# %%
# Bar chat to vissualize the count of stars with respective type
stars_df['Star type'].value_counts().plot(kind= 'bar')
plt.show()

# %% [markdown]
# 1. Add some cool customization to this simple graph
#
#   Adjust the size of the figure according to your convenience.
#
#   Add the value of counts on top of the bars.
#
#   Set the background to dark.
#
#   Change the color of each bar.
#
#   Add title.
#
#   Add ylabel and change the color of y ticks.
#
#   Replace x ticks from 0,1,2,3,4,5 to represent names of the star type.
#
#   save plots in base directory.

# %%
plt.figure(figsize= (5, 5))
plt.style.use('dark_background')
plt.ylabel('Number of Stars', color = 'white', fontsize = 12)
plt.yticks(color='tab:pink')
plt.title('Visualized Star count', color= 'blue',fontsize = 14)
ax = stars_df['Star type'].value_counts().plot(kind= 'bar', color=['brown','red','white', 'yellow', 'lightblue','orange'])
ax.bar_label(ax.containers[0], color= 'red') #Add the value of counts on top of the bars.
plt.xticks(ticks=[0,1,2,3,4,5,], labels=['Brown\nDwarf','Red\nDwarf','White\nDwarf','Main\nsequece','Super\ngiants','Hyper\ngiants'], rotation= 45, color = 'lime') #Replace x ticks from 0,1,2,3,4,5 to represent names of the star type.
plt.savefig(base_dir + 'barplot_star_count.png')
plt.show()

# %% [markdown]
# We are now using seaborns barplot to compre it with the above bar chart.
#
# Seaborn + Matplotlib

# %%
#visualizing the Star color data
ax= sns.barplot(x= stars_df['Star color'].value_counts().index,
            y= stars_df['Star color'].value_counts(),
            palette = 'viridis')
# Loop through all containers (bars) in the plot
for container in ax.containers:
    # Add labels to each container with red color and bold font weight
    ax.bar_label(container, color='red', weight='bold')

#ax.bar_label(ax.containers[0], color= 'red', weight ='bold')
plt.title('Visualizing the count of star colors', color= 'royalblue', fontsize=16 )

plt.xticks(rotation= 17, color= 'orange')
plt.ylabel('Star_count', color= 'white', fontsize = 13)
plt.yticks(color= 'tab:pink')

plt.show()
# Out:
# <ipython-input-10-095d4cdfd972>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax= sns.barplot(x= stars_df['Star color'].value_counts().index,

# %% [markdown]
# First four columns are what we are looking forward to.
# We can have a subplot with 1 row and 4 columns to visualize this.

# %%
stars_df.head(5)
# Out:
#    Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0             3068          0.002400        0.1700                   16.12
# 1             3042          0.000500        0.1542                   16.60
# 2             2600          0.000300        0.1020                   18.70
# 3             2800          0.000200        0.1600                   16.65
# 4             1939          0.000138        0.1030                   20.06
#
#    Star type Star color Spectral Class
# 0          0        Red              M
# 1          0        Red              M
# 2          0        Red              M
# 3          0        Red              M
# 4          0        Red              M

# %%
# visualize outliers in the data

sns.boxplot(x=stars_df['Star type'], y = stars_df['Temperature (K)'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
